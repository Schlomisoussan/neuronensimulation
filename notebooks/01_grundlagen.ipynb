# %% [markdown]
# # Aufgabe 1 – Grundlegende Überlegungen
#
# Analytischer Teil. Die Herleitung gehört ausführlich in den LaTeX-Bericht; hier optional zur Kontrolle.

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1a) Gültigkeit der Gleichungen (11)–(13)
#
# Zeige, dass aus (8)–(10) mit $\tau=1/(\alpha+\beta)$ und $x_\infty=\alpha/(\alpha+\beta)$ die Form (11)–(13) folgt.

# %% [markdown]
# ## 1b) Sinnvolle Anfangsbedingungen für $n, m, h$
#
# Inaktives Neuron: $U=V_\mathrm{pot}$, Gating-Variablen im Gleichgewicht $x_\infty(V_\mathrm{pot})$.

# %%
from src.hodgkin_huxley import initial_state
print(initial_state())
